# %% [markdown]
# # Create a solar input file
#
# Create a solar input file using available data.  Just an example so don't worry about time-syncing with wind

# %%
import pandas as pd

# %% [markdown]
# ## Now set up the solar file

# %%
df_solar = pd.read_csv(
    "../07_floris_standin_and_solar_pysam/inputs/Flatirons_solar_data_sunset.csv"
)

# Set up the time_utc column, then drop Timestamp
df_solar["time_utc"] = pd.to_datetime(df_solar["Timestamp"], format="ISO8601", utc=True)
df_solar = df_solar.drop(columns=["Timestamp"])

# Add a time column where 0 is time 0
# s(note this will not be time synced with wind, just for example)
df_solar["time"] = (df_solar["time_utc"] - df_solar["time_utc"].min()).dt.total_seconds()

df_solar = df_solar.reset_index(drop=True)

df_solar
# Out:
#        SRRL BMS Global Horizontal Irradiance (W/m²_irr)  \
# 0                                            735.632400
# 1                                            735.278175
# 2                                            734.923950
# 3                                            734.569725
# 4                                            734.215500
# ...                                                 ...
# 79300                                          0.000000
# 79301                                          0.000000
# 79302                                          0.000000
# 79303                                          0.000000
# 79304                                          0.000000
#
#        SRRL BMS Direct Normal Irradiance (W/m²_irr)  \
# 0                                        434.019267
# 1                                        433.804658
# 2                                        433.590050
# 3                                        433.375442
# 4                                        433.160833
# ...                                             ...
# 79300                                      0.000000
# 79301                                      0.000000
# 79302                                      0.000000
# 79303                                      0.000000
# 79304                                      0.000000
#
#        SRRL BMS Diffuse Horizontal Irradiance (W/m²_irr)  \
# 0                                             314.848133
# 1                                             314.727892
# 2                                             314.607650
# 3                                             314.487408
# 4                                             314.367167
# ...                                                  ...
# 79300                                           0.000000
# 79301                                           0.000000
# 79302                                           0.000000
# 79303                                           0.000000
# 79304                                           0.000000
#
#        SRRL BMS Dry Bulb Temperature (°C)  SRRL BMS Wind Speed at 19' (m/s)  \
# 0                               30.754667                          3.543600
# 1                               30.755583                          3.538200
# 2                               30.756500                          3.532800
# 3                               30.757417                          3.527400
# 4                               30.758333                          3.522000
# ...                                   ...                               ...
# 79300                           22.953000                          3.380533
# 79301                           22.954750                          3.388400
# 79302                           22.956500                          3.396267
# 79303                           22.958250                          3.404133
# 79304                           22.960000                          3.412000
#
#        Avg Wind Speed @ 10m [m/s]  Peak Wind Speed @ 2m [m/s]  \
# 0                        4.284200                    4.428533
# 1                        4.279275                    4.423317
# 2                        4.274350                    4.418100
# 3                        4.269425                    4.412883
# 4                        4.264500                    4.407667
# ...                           ...                         ...
# 79300                    3.986467                    4.441033
# 79301                    3.996600                    4.453025
# 79302                    4.006733                    4.465017
# 79303                    4.016867                    4.477008
# 79304                    4.027000                    4.489000
#
#        Peak Wind Speed @ 10m [m/s]                         time_utc     time
# 0                         5.378067        2024-06-24 16:59:08+00:00      0.0
# 1                         5.374008 2024-06-24 16:59:08.500000+00:00      0.5
# 2                         5.369950        2024-06-24 16:59:09+00:00      1.0
# 3                         5.365892 2024-06-24 16:59:09.500000+00:00      1.5
# 4                         5.361833        2024-06-24 16:59:10+00:00      2.0
# ...                            ...                              ...      ...
# 79300                     4.518867        2024-06-25 03:59:58+00:00  39650.0
# 79301                     4.523900 2024-06-25 03:59:58.500000+00:00  39650.5
# 79302                     4.528933        2024-06-25 03:59:59+00:00  39651.0
# 79303                     4.533967 2024-06-25 03:59:59.500000+00:00  39651.5
# 79304                     4.539000        2024-06-25 04:00:00+00:00  39652.0
#
# [79305 rows x 10 columns]

# %%
# Save the data to a new CSV file
df_solar.to_pickle("inputs/solar_input.p")
